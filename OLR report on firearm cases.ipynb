# %%
import pandas as pd
import os

# %%
df = pd.concat([pd.read_csv("data/firearm-charges-2018.csv"),
                pd.read_csv("data/firearm-charges-2013.csv"),
                pd.read_csv("data/firearm-charges-2007.csv").dropna(subset=["Year"])])

df = df[["Year","Charges","Offense","Table"]]
df.head()
# Out:
#    Year Charges                                            Offense  Table
# 0  2013       4  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
# 1  2014       3  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
# 2  2015       5  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
# 3  2016       7  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
# 4  2017      10  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0

# %%
df[(df["Year"] < 2008)&(df["Table"] == 2)]["Offense"].unique()
# Out:
# array([], dtype=object)

# %%
def asciistr(badstr):
    if pd.isnull(badstr): return badstr
    return ''.join([i if ord(i) < 128 else '' for i in badstr]).strip().replace("/"," ")
df["ascii_offense"] = df["Offense"].apply(asciistr)

# %%
import re
def statute_code(offense_str):
    if pd.isnull(offense_str): return ""
    return re.search(".* \((.*)\)",asciistr(offense_str)).group(1)

statute_code(df.iloc[20]["Offense"])
# Out:
# 'CGS  29-35(a)'

# %%
df["Statute"] = df["Offense"].apply(statute_code)
df.head()
# Out:
#    Year Charges                                            Offense  Table  \
# 0  2013       4  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
# 1  2014       3  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
# 2  2015       5  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
# 3  2016       7  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
# 4  2017      10  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...    1.0
#
#                                        ascii_offense     Statute
# 0  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...  CGS  29-28
# 1  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...  CGS  29-28
# 2  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...  CGS  29-28
# 3  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...  CGS  29-28
# 4  VIOLATING PISTOL PERMITTING REQUIREMENTS (CGS ...  CGS  29-28

# %%
statutes = df["Statute"].unique()

# %%
def plot_title(ascii_str):
    if pd.isnull(ascii_str): return ascii_str
    return ascii_str[:ascii_str.index("(")].lower().capitalize().strip()
df["Title"] = df["ascii_offense"].apply(plot_title)

# %%
def fix(val):
    return str(int(str(val).strip("*").strip().replace(",","")))


print fix("199*")
print fix("*2100")
print fix("*2100*")
# Out:
# 199
# 2100
# 2100

# %%
def fix_col(col_name):
    df[col_name] = df[col_name].apply(fix).astype(int)
fix_col("Year")
fix_col("Charges")
#fix_col("Convictions")
#fix_col("Nolle")

# %%
def exclude_01(tmpdf):
    tmpdf = tmpdf.copy().reset_index()
    # Not sure why 2001 numbers are so low. Excluding for now.
    return tmpdf[tmpdf["Year"] > 2001]

# %%
df.dtypes
# Out:
# Year               int64
# Charges            int64
# Offense           object
# Table            float64
# ascii_offense     object
# Statute           object
# Title             object
# dtype: object

# %%
df = df[["Year","Charges","Table","Title","Statute"]]

# %%
df.head()
# Out:
#    Year  Charges  Table                                     Title     Statute
# 0  2013        4    1.0  Violating pistol permitting requirements  CGS  29-28
# 1  2014        3    1.0  Violating pistol permitting requirements  CGS  29-28
# 2  2015        5    1.0  Violating pistol permitting requirements  CGS  29-28
# 3  2016        7    1.0  Violating pistol permitting requirements  CGS  29-28
# 4  2017       10    1.0  Violating pistol permitting requirements  CGS  29-28

# %%
offenses = df["Title"].unique()

# %%
# def from_peak(df):
#     ret = df.copy()
    
#     peak = float(ret.loc[ret.index[0]]["Charges"])
#     latest = float(ret.loc[ret.index[-1]]["Charges"])
    
#     return (peak - latest) * 100 / peak

# %%
def statute_df(statute):
    return df[df["Statute"] == statute].set_index("Year").sort_index()

# %%
def off_df(offense):
    ret = df[df["Title"] == offense].set_index("Year").sort_index()
    
#     ret["from_peak"] = from_peak(ret)
    
    return ret

off_df(offenses[10])
# Out:
#       Charges  Table                                              Title  \
# Year
# 2008       17    1.0  Violating loaded firearm safe storage requirem...
# 2009        7    1.0  Violating loaded firearm safe storage requirem...
# 2010       26    1.0  Violating loaded firearm safe storage requirem...
# 2011       20    1.0  Violating loaded firearm safe storage requirem...
# 2012       12    1.0  Violating loaded firearm safe storage requirem...
# 2013       10    1.0  Violating loaded firearm safe storage requirem...
# 2014       12    1.0  Violating loaded firearm safe storage requirem...
# 2015       12    1.0  Violating loaded firearm safe storage requirem...
# 2016        7    1.0  Violating loaded firearm safe storage requirem...
# 2017       13    1.0  Violating loaded firearm safe storage requirem...
#
#           Statute
# Year
# 2008  CGS  29-37i
# 2009  CGS  29-37i
# 2010  CGS  29-37i
# 2011  CGS  29-37i
# 2012  CGS  29-37i
# 2013  CGS  29-37i
# 2014  CGS  29-37i
# 2015  CGS  29-37i
# 2016  CGS  29-37i
# 2017  CGS  29-37i

# %%
import matplotlib
#matplotlib.use( "agg" )
# matplotlib.use( "macosx" )

# %matplotlib inline
# matplotlib.style.use('ggplot')
matplotlib.style.use('mirror00')
import matplotlib.pyplot as plt

# %%
def plot_offense(offdf,title="",subfolder="",figsize=(6,4)):
    
    #offdf.set_index("Year")
    
    print offdf.index
    
    tmpdf = exclude_01(offdf.copy())
    fname = tmpdf["Title"][tmpdf.index[0]]
    ax = tmpdf["Charges"].plot.bar(figsize=figsize)
    ax.set_xlabel("")
    #ax.set_title(off_df["title"].iloc[0])
    ax.set_title(title)
    
    ax.set_xticklabels(tmpdf["Year"])
        
    plt.tight_layout()
    
    plt.savefig(os.path.join("img", subfolder, fname + ".png"),
                bbox_inches="tight")
    
    plt.close()


plot_offense(off_df(offenses[10]))
# Out:
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')

# %%
for statute in statutes:
    tmpdf = statute_df(statute)
    if tmpdf["Charges"].max() > 100:
#         print off
        plot_offense(tmpdf, subfolder="over-50",figsize=(6,4))
    try:
        plot_offense(tmpdf)
    except:
        print tmpdf
# Out:
# Int64Index([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#             2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2005, 2006, 2008, 2009, 2010, 2013], dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2002, 2003, 2003, 2004, 2004, 2005, 2005, 2006, 2007,
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2002, 2003, 2003, 2004, 2004, 2005, 2005, 2006, 2007,
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2003, 2008, 2009, 2012, 2015, 2017], dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2011, 2012, 2014, 2015,
#             2016],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#             2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#             2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2004, 2005, 2009, 2010, 2015], dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#             2017],
#            dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2004, 2005, 2007, 2009, 2010, 2011, 2012, 2014, 2015,
#             2016],
#            dtype='int64', name=u'Year')
# Int64Index([2005, 2012, 2017], dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2012, 2014, 2015,
#             2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2004, 2005, 2006, 2008, 2010, 2012, 2013, 2014, 2015,
#             2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2003, 2004, 2005, 2007, 2009, 2013, 2015], dtype='int64', name=u'Year')
# Int64Index([2016], dtype='int64', name=u'Year')
# Int64Index([2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#             2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2014], dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2002, 2003, 2003, 2004, 2005, 2005, 2006, 2006, 2007,
#             2007, 2008, 2008, 2009, 2009, 2010, 2010, 2011, 2011, 2012, 2012,
#             2013, 2013, 2014, 2014, 2015, 2015, 2016, 2016, 2017, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2002, 2004, 2005, 2006, 2007, 2009, 2010, 2013, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2012, 2014, 2017], dtype='int64', name=u'Year')
# Int64Index([2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2012, 2013,
#             2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2009, 2012, 2013, 2014, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2017], dtype='int64', name=u'Year')
# Int64Index([2009, 2010, 2011, 2013, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2016, 2017], dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')
# Int64Index([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2012], dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2005, 2008], dtype='int64', name=u'Year')
# Int64Index([2004, 2005, 2008], dtype='int64', name=u'Year')
# Int64Index([2011], dtype='int64', name=u'Year')
#       Charges  Table Title Statute
# Year
# 2011        2    1.0   NaN
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012],
#            dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012],
#            dtype='int64', name=u'Year')
# Int64Index([2006, 2007, 2008, 2010, 2012], dtype='int64', name=u'Year')
# Int64Index([2004, 2006], dtype='int64', name=u'Year')
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007], dtype='int64', name=u'Year')

# %%
# for off in offenses:
#     tmpdf = off_df(off)
#     if tmpdf["Charges"].max() > 100:
#         print off
#         plot_offense(tmpdf, subfolder="over-50",figsize=(6,4))
#     try:
#         plot_offense(tmpdf)
#     except:
#         print tmpdf

# %%
def prev_avg(tmpdf):
    tmpdf = tmpdf.copy().reset_index()
    years = tmpdf["Year"]
    years_to_average =  filter(lambda x: x != 2017, years)
    good_year = lambda x: x != 2017
    return tmpdf[tmpdf["Year"].apply(good_year)]["Charges"].mean()
    
    
prev_avg(off_df(offenses[10]))
# Out:
# 13.666666666666666

# %%
rows = []

for statute in statutes:
    tmpdf = statute_df(statute)
    if tmpdf["Charges"].max() > 0 and 2017 in tmpdf.index:

    #if tmpdf["Charges"].max() > 300 and 2017 in tmpdf.index:
        tmpdf = tmpdf.sort_values(by="Charges",ascending=False)
        peak_row = tmpdf.reset_index().iloc[0]

        if 2017 in tmpdf.index:
            count2017 = tmpdf.loc[2017]["Charges"]
        else:
            count2017 = 0
            
        previous_average = prev_avg(tmpdf)
        diff_avg = previous_average - count2017
        #diff_avg_pct = diff_avg / previous_average
        obj = {
                "statute":statute,
                "offense":peak_row["Title"],
                "peak_year":peak_row["Year"],
                "peak":peak_row["Charges"],
                "2017":count2017,
                "diff": peak_row["Charges"] - count2017,
                "prev_avg": int(previous_average.round()),
                "diff_avg": diff_avg,
                "table":tmpdf.iloc[0]["Table"]
        }
        
        print obj 
        
        rows.append(obj)
        
top_df = pd.DataFrame(rows).set_index("statute")
top_df["diff_pct"] = top_df["diff"] * 100 / top_df["peak"]
top_df["diff_avg_pct"] = top_df["diff_avg"] * 100 / top_df["prev_avg"]

#top_df["diff_pct"] = top_df["diff_pct"].apply(lambda x: round(x,1))
#top_df["diff_avg_pct"] = top_df["diff_avg_pct"].apply(lambda x: round(x,1))

top_df["Sentence"] = top_df.index + " charges dropped " + top_df["diff_pct"].astype(str) + " percent "\
+ " from a " + top_df["peak_year"].astype(str) + " peak of " + top_df["peak"].astype(str)\
+ " to " + top_df["2017"].astype(str) + " in 2017."

top_df["Sentence2"] = top_df.index + " charges dropped " + top_df["diff_avg_pct"].astype(str) + " percent "\
+ " from a 15-year average of " + top_df["prev_avg"].astype(str)\
+ " to " + top_df["2017"].astype(str) + " in 2017."

top_df["Sentence3"] = "<strong>" + top_df.index + " charges</strong> dropped " + top_df["diff_avg_pct"].astype(str) + " percent "\
+ " from a 15-year average of " + top_df["prev_avg"].astype(str)\
+ " to " + top_df["2017"].astype(str) + " in 2017."\
+ " Charges for this offense peaked at " + top_df["peak"].astype(str) + " in " + top_df["peak_year"].astype(str) + "."


top_df
# Out:
# {'statute': 'CGS  29-28', 'peak': 10, 'prev_avg': 5, 'diff': 0, 'diff_avg': -4.9333333333333336, 'offense': 'Violating pistol permitting requirements', '2017': 10, 'table': 1.0, 'peak_year': 2010}
# {'statute': 'CGS  29-33', 'peak': 206, 'prev_avg': 64, 'diff': 127, 'diff_avg': -15.047619047619051, 'offense': 'Illegally transferring a pistol or revolver', '2017': 79, 'table': 1.0, 'peak_year': 2011}
# {'statute': 'CGS  29-34(a)', 'peak': 2, 'prev_avg': 1, 'diff': 0, 'diff_avg': -0.80000000000000004, 'offense': 'Making false statements related to a pistol or revolver transfer', '2017': 2, 'table': 1.0, 'peak_year': 2012}
# {'statute': 'CGS  29-35(a)', 'peak': 681, 'prev_avg': 581, 'diff': 32, 'diff_avg': -68.25, 'offense': 'Carrying a pistol without a permit', '2017': 649, 'table': 1.0, 'peak_year': 2008}
# {'statute': 'CGS  29-35(b)', 'peak': 112, 'prev_avg': 8, 'diff': 0, 'diff_avg': -103.86666666666667, 'offense': 'Failing to carry a pistol permit', '2017': 112, 'table': 1.0, 'peak_year': 2017}
# {'statute': 'CGS  29-36', 'peak': 115, 'prev_avg': 88, 'diff': 0, 'diff_avg': -27.1875, 'offense': 'Altering firearm identification mark, number, or name', '2017': 115, 'table': 1.0, 'peak_year': 2017}
# {'statute': 'CGS  29-37e', 'peak': 22, 'prev_avg': 7, 'diff': 16, 'diff_avg': 0.72727272727272751, 'offense': 'Making a false statement related to transferring a firearm other than a pistol or revolver', '2017': 6, 'table': 1.0, 'peak_year': 2009}
# {'statute': 'CGS  29-37i', 'peak': 26, 'prev_avg': 14, 'diff': 13, 'diff_avg': 0.66666666666666607, 'offense': 'Violating loaded firearm safe storage requirements with respect to minors', '2017': 13, 'table': 1.0, 'peak_year': 2010}
# {'statute': 'CGS  29-37j(c)', 'peak': 2, 'prev_avg': 2, 'diff': 1, 'diff_avg': 1.0, 'offense': 'Purchase or soliciting purchase of a firearm for transfer to a prohibited person and prior felony conviction within five years', '2017': 1, 'table': nan, 'peak_year': 2005}
# {'statute': 'CGS  53-202(b)', 'peak': 9, 'prev_avg': 2, 'diff': 7, 'diff_avg': 0.083333333333333481, 'offense': 'Using machine gun in a violent crime', '2017': 2, 'table': nan, 'peak_year': 2002}
# {'statute': 'CGS  53-202(c)', 'peak': 9, 'prev_avg': 4, 'diff': 6, 'diff_avg': 1.5, 'offense': 'Use machine gun for an aggressive purpose', '2017': 3, 'table': nan, 'peak_year': 2004}
# {'statute': 'CGS  53-202b(a)(1)', 'peak': 22, 'prev_avg': 7, 'diff': 18, 'diff_avg': 2.7142857142857144, 'offense': 'Illegally transferring an assault weapon', '2017': 4, 'table': 1.0, 'peak_year': 2015}
# {'statute': 'CGS  53-202c', 'peak': 59, 'prev_avg': 21, 'diff': Year
# 2017    27
# 2017    44
# Name: Charges, dtype: int64, 'diff_avg': Year
# 2017   -10.566667
# 2017     6.433333
# Name: Charges, dtype: float64, 'offense': 'Illegally possessing an assault weapon1st time violator whose possession was previously legal', '2017': Year
# 2017    32
# 2017    15
# Name: Charges, dtype: int64, 'table': 1.0, 'peak_year': 2016}
# {'statute': 'CGS  53-202f', 'peak': 7, 'prev_avg': 2, 'diff': 0, 'diff_avg': -5.2000000000000002, 'offense': 'Illegally transporting an assault weapon', '2017': 7, 'table': 1.0, 'peak_year': 2017}
# {'statute': 'CGS  53-202g', 'peak': 7, 'prev_avg': 5, 'diff': 4, 'diff_avg': 1.75, 'offense': 'Failing to report a lost or stolen assault weapon', '2017': 3, 'table': 1.0, 'peak_year': 2012}
# {'statute': 'CGS  53-202k', 'peak': 44, 'prev_avg': 18, 'diff': 29, 'diff_avg': 2.9375, 'offense': 'Use firearm to commit a class a, b, or c felony', '2017': 15, 'table': nan, 'peak_year': 2006}
# {'statute': 'CGS  53-202l', 'peak': 1, 'prev_avg': 1, 'diff': 0, 'diff_avg': 0.0, 'offense': 'Transferring amor piercing or incendiary ammunition', '2017': 1, 'table': 1.0, 'peak_year': 2012}
# {'statute': 'CGS  53-202aa', 'peak': 17, 'prev_avg': 11, 'diff': 7, 'diff_avg': 1.4000000000000004, 'offense': 'Trafficking in firearms', '2017': 10, 'table': 1.0, 'peak_year': 2015}
# {'statute': 'CGS  53-203', 'peak': 205, 'prev_avg': 169, 'diff': 35, 'diff_avg': -1.25, 'offense': 'Illegal discharge of firearm', '2017': 170, 'table': nan, 'peak_year': 2006}
# {'statute': 'CGS  53-204', 'peak': 18, 'prev_avg': 6, 'diff': 16, 'diff_avg': 4.0714285714285712, 'offense': 'Hunting or discharging a firearm from a public highway', '2017': 2, 'table': 1.0, 'peak_year': 2014}
# {'statute': 'CGS  53-205', 'peak': 18, 'prev_avg': 11, 'diff': 14, 'diff_avg': 7.4375, 'offense': 'Carrying a loaded shotgun, rifle, or muzzleloader in a vehicle or snowmobile', '2017': 4, 'table': 1.0, 'peak_year': 2010}
# {'statute': 'CGS  53-206c', 'peak': 86, 'prev_avg': 79, 'diff': 15, 'diff_avg': 8.0, 'offense': 'Selling, carrying, brandishing a facsimile firearm', '2017': 71, 'table': 1.0, 'peak_year': 2014}
# {'statute': 'CGS  53-206d(a)', 'peak': 94, 'prev_avg': 72, 'diff': 3, 'diff_avg': -18.777777777777771, 'offense': 'Carrying a loaded firearm under the influence of drugs or alcohol', '2017': 91, 'table': 1.0, 'peak_year': 2013}
# {'statute': 'CGS  53a-55a', 'peak': 29, 'prev_avg': 18, 'diff': 12, 'diff_avg': 0.55555555555555713, 'offense': '1st degree manslaughter with a firearm', '2017': 17, 'table': 1.0, 'peak_year': 2016}
# {'statute': 'CGS  53a-56a', 'peak': 3, 'prev_avg': 2, 'diff': 2, 'diff_avg': 1.25, 'offense': '2nd degree manslaughter with a firearm', '2017': 1, 'table': 1.0, 'peak_year': 2009}
# {'statute': 'CGS  53a-60a', 'peak': 34, 'prev_avg': 20, 'diff': 20, 'diff_avg': 6.4444444444444429, 'offense': '2nd degree assault with a firearm', '2017': 14, 'table': 1.0, 'peak_year': 2012}
# {'statute': 'CGS  53a-60c', 'peak': 4, 'prev_avg': 3, 'diff': 2, 'diff_avg': 0.66666666666666652, 'offense': '2nd degree assault of an elderly, blind, disabled, pregnant, or intellectually disabled person with a firearm', '2017': 2, 'table': 1.0, 'peak_year': 2011}
# {'statute': 'CGS  53a-72b', 'peak': 2, 'prev_avg': 1, 'diff': 0, 'diff_avg': -0.75, 'offense': '3rd degree sexual assault with a firearm', '2017': 2, 'table': 1.0, 'peak_year': 2013}
# {'statute': 'CGS  53a-92a', 'peak': 38, 'prev_avg': 26, 'diff': 28, 'diff_avg': 16.0, 'offense': '1st degree kidnapping with a firearm', '2017': 10, 'table': 1.0, 'peak_year': 2013}
# {'statute': 'CGS  53a-94a', 'peak': 13, 'prev_avg': 5, 'diff': 7, 'diff_avg': -1.2222222222222223, 'offense': '2nd degree kidnapping with a firearm', '2017': 6, 'table': 1.0, 'peak_year': 2009}
# {'statute': 'CGS  53a-102a', 'peak': 10, 'prev_avg': 4, 'diff': 7, 'diff_avg': 1.0, 'offense': '2nd degree burlary with a firearm', '2017': 3, 'table': 1.0, 'peak_year': 2008}
# {'statute': 'CGS  53a-103a', 'peak': 9, 'prev_avg': 6, 'diff': 8, 'diff_avg': 5.0, 'offense': '3rd degree burglary with a firearm', '2017': 1, 'table': 1.0, 'peak_year': 2008}
# {'statute': 'CGS  53a-211', 'peak': 63, 'prev_avg': 40, 'diff': 33, 'diff_avg': 9.75, 'offense': 'Possessing a sawed-off shotgun or silencer', '2017': 30, 'table': 1.0, 'peak_year': 2008}
# {'statute': 'CGS  53a-212', 'peak': 470, 'prev_avg': 351, 'diff': 162, 'diff_avg': 43.3125, 'offense': 'Stealing a firearm', '2017': 308, 'table': nan, 'peak_year': 2005}
# {'statute': 'CGS  53a-216', 'peak': 92, 'prev_avg': 59, 'diff': 59, 'diff_avg': 26.1875, 'offense': 'Criminal use of firearm or electronic defense weapon', '2017': 33, 'table': nan, 'peak_year': 2006}
# {'statute': 'CGS  53a-217', 'peak': 640, 'prev_avg': 434, 'diff': 48, 'diff_avg': -157.625, 'offense': 'Criminal possession of a firearm or electronic defense weapon', '2017': 592, 'table': 1.0, 'peak_year': 2013}
# {'statute': 'CGS  53a-217a', 'peak': 18, 'prev_avg': 10, 'diff': 13, 'diff_avg': 5.125, 'offense': 'Criminally negligent storage of a firearm', '2017': 5, 'table': 1.0, 'peak_year': 2013}
# {'statute': 'CGS  53a-217c', 'peak': 372, 'prev_avg': 278, 'diff': 91, 'diff_avg': -3.3125, 'offense': 'Criminal possession of a pistol or revolver', '2017': 281, 'table': 1.0, 'peak_year': 2011}
# {'statute': 'CGS  29-38', 'peak': 1273, 'prev_avg': 984, 'diff': 341, 'diff_avg': 51.875, 'offense': 'Possessing a weapon in a vehicle', '2017': 932, 'table': 2.0, 'peak_year': 2008}
# {'statute': 'CGS  53-206', 'peak': 1012, 'prev_avg': 837, 'diff': 399, 'diff_avg': 224.1875, 'offense': 'Carrying a dangerous weapon', '2017': 613, 'table': 2.0, 'peak_year': 2006}
# {'statute': 'CGS  53a-217b', 'peak': 35, 'prev_avg': 21, 'diff': 23, 'diff_avg': 8.9375, 'offense': 'Possess firearm or deadly weapon on school ground', '2017': 12, 'table': 2.0, 'peak_year': 2005}
#                                                                  2017  \
# statute
# CGS  29-28                                                         10
# CGS  29-33                                                         79
# CGS  29-34(a)                                                       2
# CGS  29-35(a)                                                     649
# CGS  29-35(b)                                                     112
# CGS  29-36                                                        115
# CGS  29-37e                                                         6
# CGS  29-37i                                                        13
# CGS  29-37j(c)                                                      1
# CGS  53-202(b)                                                      2
# CGS  53-202(c)                                                      3
# CGS  53-202b(a)(1)                                                  4
# CGS  53-202c        Year
# 2017    32
# 2017    15
# Name: Charges, dtyp...
# CGS  53-202f                                                        7
# CGS  53-202g                                                        3
# CGS  53-202k                                                       15
# CGS  53-202l                                                        1
# CGS  53-202aa                                                      10
# CGS  53-203                                                       170
# CGS  53-204                                                         2
# CGS  53-205                                                         4
# CGS  53-206c                                                       71
# CGS  53-206d(a)                                                    91
# CGS  53a-55a                                                       17
# CGS  53a-56a                                                        1
# CGS  53a-60a                                                       14
# CGS  53a-60c                                                        2
# CGS  53a-72b                                                        2
# CGS  53a-92a                                                       10
# CGS  53a-94a                                                        6
# CGS  53a-102a                                                       3
# CGS  53a-103a                                                       1
# CGS  53a-211                                                       30
# CGS  53a-212                                                      308
# CGS  53a-216                                                       33
# CGS  53a-217                                                      592
# CGS  53a-217a                                                       5
# CGS  53a-217c                                                     281
# CGS  29-38                                                        932
# CGS  53-206                                                       613
# CGS  53a-217b                                                      12
#
#                                                                  diff  \
# statute
# CGS  29-28                                                          0
# CGS  29-33                                                        127
# CGS  29-34(a)                                                       0
# CGS  29-35(a)                                                      32
# CGS  29-35(b)                                                       0
# CGS  29-36                                                          0
# CGS  29-37e                                                        16
# CGS  29-37i                                                        13
# CGS  29-37j(c)                                                      1
# CGS  53-202(b)                                                      7
# CGS  53-202(c)                                                      6
# CGS  53-202b(a)(1)                                                 18
# CGS  53-202c        Year
# 2017    27
# 2017    44
# Name: Charges, dtyp...
# CGS  53-202f                                                        0
# CGS  53-202g                                                        4
# CGS  53-202k                                                       29
# CGS  53-202l                                                        0
# CGS  53-202aa                                                       7
# CGS  53-203                                                        35
# CGS  53-204                                                        16
# CGS  53-205                                                        14
# CGS  53-206c                                                       15
# CGS  53-206d(a)                                                     3
# CGS  53a-55a                                                       12
# CGS  53a-56a                                                        2
# CGS  53a-60a                                                       20
# CGS  53a-60c                                                        2
# CGS  53a-72b                                                        0
# CGS  53a-92a                                                       28
# CGS  53a-94a                                                        7
# CGS  53a-102a                                                       7
# CGS  53a-103a                                                       8
# CGS  53a-211                                                       33
# CGS  53a-212                                                      162
# CGS  53a-216                                                       59
# CGS  53a-217                                                       48
# CGS  53a-217a                                                      13
# CGS  53a-217c                                                      91
# CGS  29-38                                                        341
# CGS  53-206                                                       399
# CGS  53a-217b                                                      23
#
#                                                              diff_avg  \
# statute
# CGS  29-28                                                   -4.93333
# CGS  29-33                                                   -15.0476
# CGS  29-34(a)                                                    -0.8
# CGS  29-35(a)                                                  -68.25
# CGS  29-35(b)                                                -103.867
# CGS  29-36                                                   -27.1875
# CGS  29-37e                                                  0.727273
# CGS  29-37i                                                  0.666667
# CGS  29-37j(c)                                                      1
# CGS  53-202(b)                                              0.0833333
# CGS  53-202(c)                                                    1.5
# CGS  53-202b(a)(1)                                            2.71429
# CGS  53-202c        Year
# 2017   -10.566667
# 2017     6.433333
# Name:...
# CGS  53-202f                                                     -5.2
# CGS  53-202g                                                     1.75
# CGS  53-202k                                                   2.9375
# CGS  53-202l                                                        0
# CGS  53-202aa                                                     1.4
# CGS  53-203                                                     -1.25
# CGS  53-204                                                   4.07143
# CGS  53-205                                                    7.4375
# CGS  53-206c                                                        8
# CGS  53-206d(a)                                              -18.7778
# CGS  53a-55a                                                 0.555556
# CGS  53a-56a                                                     1.25
# CGS  53a-60a                                                  6.44444
# CGS  53a-60c                                                 0.666667
# CGS  53a-72b                                                    -0.75
# CGS  53a-92a                                                       16
# CGS  53a-94a                                                 -1.22222
# CGS  53a-102a                                                       1
# CGS  53a-103a                                                       5
# CGS  53a-211                                                     9.75
# CGS  53a-212                                                  43.3125
# CGS  53a-216                                                  26.1875
# CGS  53a-217                                                 -157.625
# CGS  53a-217a                                                   5.125
# CGS  53a-217c                                                 -3.3125
# CGS  29-38                                                     51.875
# CGS  53-206                                                   224.188
# CGS  53a-217b                                                  8.9375
#
#                                                               offense  peak  \
# statute
# CGS  29-28                   Violating pistol permitting requirements    10
# CGS  29-33                Illegally transferring a pistol or revolver   206
# CGS  29-34(a)       Making false statements related to a pistol or...     2
# CGS  29-35(a)                      Carrying a pistol without a permit   681
# CGS  29-35(b)                        Failing to carry a pistol permit   112
# CGS  29-36          Altering firearm identification mark, number, ...   115
# CGS  29-37e         Making a false statement related to transferri...    22
# CGS  29-37i         Violating loaded firearm safe storage requirem...    26
# CGS  29-37j(c)      Purchase or soliciting purchase of a firearm f...     2
# CGS  53-202(b)                   Using machine gun in a violent crime     9
# CGS  53-202(c)              Use machine gun for an aggressive purpose     9
# CGS  53-202b(a)(1)           Illegally transferring an assault weapon    22
# CGS  53-202c        Illegally possessing an assault weapon1st time...    59
# CGS  53-202f                 Illegally transporting an assault weapon     7
# CGS  53-202g        Failing to report a lost or stolen assault weapon     7
# CGS  53-202k          Use firearm to commit a class a, b, or c felony    44
# CGS  53-202l        Transferring amor piercing or incendiary ammun...     1
# CGS  53-202aa                                 Trafficking in firearms    17
# CGS  53-203                              Illegal discharge of firearm   205
# CGS  53-204         Hunting or discharging a firearm from a public...    18
# CGS  53-205         Carrying a loaded shotgun, rifle, or muzzleloa...    18
# CGS  53-206c        Selling, carrying, brandishing a facsimile fir...    86
# CGS  53-206d(a)     Carrying a loaded firearm under the influence ...    94
# CGS  53a-55a                   1st degree manslaughter with a firearm    29
# CGS  53a-56a                   2nd degree manslaughter with a firearm     3
# CGS  53a-60a                        2nd degree assault with a firearm    34
# CGS  53a-60c        2nd degree assault of an elderly, blind, disab...     4
# CGS  53a-72b                 3rd degree sexual assault with a firearm     2
# CGS  53a-92a                     1st degree kidnapping with a firearm    38
# CGS  53a-94a                     2nd degree kidnapping with a firearm    13
# CGS  53a-102a                       2nd degree burlary with a firearm    10
# CGS  53a-103a                      3rd degree burglary with a firearm     9
# CGS  53a-211               Possessing a sawed-off shotgun or silencer    63
# CGS  53a-212                                       Stealing a firearm   470
# CGS  53a-216        Criminal use of firearm or electronic defense ...    92
# CGS  53a-217        Criminal possession of a firearm or electronic...   640
# CGS  53a-217a               Criminally negligent storage of a firearm    18
# CGS  53a-217c             Criminal possession of a pistol or revolver   372
# CGS  29-38                           Possessing a weapon in a vehicle  1273
# CGS  53-206                               Carrying a dangerous weapon  1012
# CGS  53a-217b       Possess firearm or deadly weapon on school ground    35
#
#                     peak_year  prev_avg  table  \
# statute
# CGS  29-28               2010         5    1.0
# CGS  29-33               2011        64    1.0
# CGS  29-34(a)            2012         1    1.0
# CGS  29-35(a)            2008       581    1.0
# CGS  29-35(b)            2017         8    1.0
# CGS  29-36               2017        88    1.0
# CGS  29-37e              2009         7    1.0
# CGS  29-37i              2010        14    1.0
# CGS  29-37j(c)           2005         2    NaN
# CGS  53-202(b)           2002         2    NaN
# CGS  53-202(c)           2004         4    NaN
# CGS  53-202b(a)(1)       2015         7    1.0
# CGS  53-202c             2016        21    1.0
# CGS  53-202f             2017         2    1.0
# CGS  53-202g             2012         5    1.0
# CGS  53-202k             2006        18    NaN
# CGS  53-202l             2012         1    1.0
# CGS  53-202aa            2015        11    1.0
# CGS  53-203              2006       169    NaN
# CGS  53-204              2014         6    1.0
# CGS  53-205              2010        11    1.0
# CGS  53-206c             2014        79    1.0
# CGS  53-206d(a)          2013        72    1.0
# CGS  53a-55a             2016        18    1.0
# CGS  53a-56a             2009         2    1.0
# CGS  53a-60a             2012        20    1.0
# CGS  53a-60c             2011         3    1.0
# CGS  53a-72b             2013         1    1.0
# CGS  53a-92a             2013        26    1.0
# CGS  53a-94a             2009         5    1.0
# CGS  53a-102a            2008         4    1.0
# CGS  53a-103a            2008         6    1.0
# CGS  53a-211             2008        40    1.0
# CGS  53a-212             2005       351    NaN
# CGS  53a-216             2006        59    NaN
# CGS  53a-217             2013       434    1.0
# CGS  53a-217a            2013        10    1.0
# CGS  53a-217c            2011       278    1.0
# CGS  29-38               2008       984    2.0
# CGS  53-206              2006       837    2.0
# CGS  53a-217b            2005        21    2.0
#
#                                                              diff_pct  \
# statute
# CGS  29-28                                                          0
# CGS  29-33                                                    61.6505
# CGS  29-34(a)                                                       0
# CGS  29-35(a)                                                 4.69897
# CGS  29-35(b)                                                       0
# CGS  29-36                                                          0
# CGS  29-37e                                                   72.7273
# CGS  29-37i                                                        50
# CGS  29-37j(c)                                                     50
# CGS  53-202(b)                                                77.7778
# CGS  53-202(c)                                                66.6667
# CGS  53-202b(a)(1)                                            81.8182
# CGS  53-202c        Year
# 2017    45.762712
# 2017    74.576271
# Name:...
# CGS  53-202f                                                        0
# CGS  53-202g                                                  57.1429
# CGS  53-202k                                                  65.9091
# CGS  53-202l                                                        0
# CGS  53-202aa                                                 41.1765
# CGS  53-203                                                   17.0732
# CGS  53-204                                                   88.8889
# CGS  53-205                                                   77.7778
# CGS  53-206c                                                  17.4419
# CGS  53-206d(a)                                               3.19149
# CGS  53a-55a                                                  41.3793
# CGS  53a-56a                                                  66.6667
# CGS  53a-60a                                                  58.8235
# CGS  53a-60c                                                       50
# CGS  53a-72b                                                        0
# CGS  53a-92a                                                  73.6842
# CGS  53a-94a                                                  53.8462
# CGS  53a-102a                                                      70
# CGS  53a-103a                                                 88.8889
# CGS  53a-211                                                   52.381
# CGS  53a-212                                                  34.4681
# CGS  53a-216                                                  64.1304
# CGS  53a-217                                                      7.5
# CGS  53a-217a                                                 72.2222
# CGS  53a-217c                                                 24.4624
# CGS  29-38                                                    26.7871
# CGS  53-206                                                   39.4269
# CGS  53a-217b                                                 65.7143
#
#                                                          diff_avg_pct  \
# statute
# CGS  29-28                                                   -98.6667
# CGS  29-33                                                   -23.5119
# CGS  29-34(a)                                                     -80
# CGS  29-35(a)                                                 -11.747
# CGS  29-35(b)                                                -1298.33
# CGS  29-36                                                   -30.8949
# CGS  29-37e                                                   10.3896
# CGS  29-37i                                                    4.7619
# CGS  29-37j(c)                                                     50
# CGS  53-202(b)                                                4.16667
# CGS  53-202(c)                                                   37.5
# CGS  53-202b(a)(1)                                            38.7755
# CGS  53-202c        Year
# 2017   -50.317460
# 2017    30.634921
# Name:...
# CGS  53-202f                                                     -260
# CGS  53-202g                                                       35
# CGS  53-202k                                                  16.3194
# CGS  53-202l                                                        0
# CGS  53-202aa                                                 12.7273
# CGS  53-203                                                 -0.739645
# CGS  53-204                                                   67.8571
# CGS  53-205                                                   67.6136
# CGS  53-206c                                                  10.1266
# CGS  53-206d(a)                                              -26.0802
# CGS  53a-55a                                                  3.08642
# CGS  53a-56a                                                     62.5
# CGS  53a-60a                                                  32.2222
# CGS  53a-60c                                                  22.2222
# CGS  53a-72b                                                      -75
# CGS  53a-92a                                                  61.5385
# CGS  53a-94a                                                 -24.4444
# CGS  53a-102a                                                      25
# CGS  53a-103a                                                 83.3333
# CGS  53a-211                                                   24.375
# CGS  53a-212                                                  12.3397
# CGS  53a-216                                                  44.3856
# CGS  53a-217                                                 -36.3191
# CGS  53a-217a                                                   51.25
# CGS  53a-217c                                                -1.19155
# CGS  29-38                                                    5.27185
# CGS  53-206                                                   26.7846
# CGS  53a-217b                                                 42.5595
#
#                                                              Sentence  \
# statute
# CGS  29-28          CGS  29-28 charges dropped 0.0 percent  from a...
# CGS  29-33          CGS  29-33 charges dropped 61.6504854369 perce...
# CGS  29-34(a)       CGS  29-34(a) charges dropped 0.0 percent  fro...
# CGS  29-35(a)       CGS  29-35(a) charges dropped 4.69897209985 pe...
# CGS  29-35(b)       CGS  29-35(b) charges dropped 0.0 percent  fro...
# CGS  29-36          CGS  29-36 charges dropped 0.0 percent  from a...
# CGS  29-37e         CGS  29-37e charges dropped 72.7272727273 perc...
# CGS  29-37i         CGS  29-37i charges dropped 50.0 percent  from...
# CGS  29-37j(c)      CGS  29-37j(c) charges dropped 50.0 percent  f...
# CGS  53-202(b)      CGS  53-202(b) charges dropped 77.7777777778 p...
# CGS  53-202(c)      CGS  53-202(c) charges dropped 66.6666666667 p...
# CGS  53-202b(a)(1)  CGS  53-202b(a)(1) charges dropped 81.81818181...
# CGS  53-202c        CGS  53-202c charges dropped Year\n2017    45....
# CGS  53-202f        CGS  53-202f charges dropped 0.0 percent  from...
# CGS  53-202g        CGS  53-202g charges dropped 57.1428571429 per...
# CGS  53-202k        CGS  53-202k charges dropped 65.9090909091 per...
# CGS  53-202l        CGS  53-202l charges dropped 0.0 percent  from...
# CGS  53-202aa       CGS  53-202aa charges dropped 41.1764705882 pe...
# CGS  53-203         CGS  53-203 charges dropped 17.0731707317 perc...
# CGS  53-204         CGS  53-204 charges dropped 88.8888888889 perc...
# CGS  53-205         CGS  53-205 charges dropped 77.7777777778 perc...
# CGS  53-206c        CGS  53-206c charges dropped 17.4418604651 per...
# CGS  53-206d(a)     CGS  53-206d(a) charges dropped 3.1914893617 p...
# CGS  53a-55a        CGS  53a-55a charges dropped 41.3793103448 per...
# CGS  53a-56a        CGS  53a-56a charges dropped 66.6666666667 per...
# CGS  53a-60a        CGS  53a-60a charges dropped 58.8235294118 per...
# CGS  53a-60c        CGS  53a-60c charges dropped 50.0 percent  fro...
# CGS  53a-72b        CGS  53a-72b charges dropped 0.0 percent  from...
# CGS  53a-92a        CGS  53a-92a charges dropped 73.6842105263 per...
# CGS  53a-94a        CGS  53a-94a charges dropped 53.8461538462 per...
# CGS  53a-102a       CGS  53a-102a charges dropped 70.0 percent  fr...
# CGS  53a-103a       CGS  53a-103a charges dropped 88.8888888889 pe...
# CGS  53a-211        CGS  53a-211 charges dropped 52.380952381 perc...
# CGS  53a-212        CGS  53a-212 charges dropped 34.4680851064 per...
# CGS  53a-216        CGS  53a-216 charges dropped 64.1304347826 per...
# CGS  53a-217        CGS  53a-217 charges dropped 7.5 percent  from...
# CGS  53a-217a       CGS  53a-217a charges dropped 72.2222222222 pe...
# CGS  53a-217c       CGS  53a-217c charges dropped 24.4623655914 pe...
# CGS  29-38          CGS  29-38 charges dropped 26.7871170463 perce...
# CGS  53-206         CGS  53-206 charges dropped 39.4268774704 perc...
# CGS  53a-217b       CGS  53a-217b charges dropped 65.7142857143 pe...
#
#                                                             Sentence2  \
# statute
# CGS  29-28          CGS  29-28 charges dropped -98.6666666667 perc...
# CGS  29-33          CGS  29-33 charges dropped -23.5119047619 perc...
# CGS  29-34(a)       CGS  29-34(a) charges dropped -80.0 percent  f...
# CGS  29-35(a)       CGS  29-35(a) charges dropped -11.7469879518 p...
# CGS  29-35(b)       CGS  29-35(b) charges dropped -1298.33333333 p...
# CGS  29-36          CGS  29-36 charges dropped -30.8948863636 perc...
# CGS  29-37e         CGS  29-37e charges dropped 10.3896103896 perc...
# CGS  29-37i         CGS  29-37i charges dropped 4.7619047619 perce...
# CGS  29-37j(c)      CGS  29-37j(c) charges dropped 50.0 percent  f...
# CGS  53-202(b)      CGS  53-202(b) charges dropped 4.16666666667 p...
# CGS  53-202(c)      CGS  53-202(c) charges dropped 37.5 percent  f...
# CGS  53-202b(a)(1)  CGS  53-202b(a)(1) charges dropped 38.77551020...
# CGS  53-202c        CGS  53-202c charges dropped Year\n2017   -50....
# CGS  53-202f        CGS  53-202f charges dropped -260.0 percent  f...
# CGS  53-202g        CGS  53-202g charges dropped 35.0 percent  fro...
# CGS  53-202k        CGS  53-202k charges dropped 16.3194444444 per...
# CGS  53-202l        CGS  53-202l charges dropped 0.0 percent  from...
# CGS  53-202aa       CGS  53-202aa charges dropped 12.7272727273 pe...
# CGS  53-203         CGS  53-203 charges dropped -0.739644970414 pe...
# CGS  53-204         CGS  53-204 charges dropped 67.8571428571 perc...
# CGS  53-205         CGS  53-205 charges dropped 67.6136363636 perc...
# CGS  53-206c        CGS  53-206c charges dropped 10.1265822785 per...
# CGS  53-206d(a)     CGS  53-206d(a) charges dropped -26.0802469136...
# CGS  53a-55a        CGS  53a-55a charges dropped 3.08641975309 per...
# CGS  53a-56a        CGS  53a-56a charges dropped 62.5 percent  fro...
# CGS  53a-60a        CGS  53a-60a charges dropped 32.2222222222 per...
# CGS  53a-60c        CGS  53a-60c charges dropped 22.2222222222 per...
# CGS  53a-72b        CGS  53a-72b charges dropped -75.0 percent  fr...
# CGS  53a-92a        CGS  53a-92a charges dropped 61.5384615385 per...
# CGS  53a-94a        CGS  53a-94a charges dropped -24.4444444444 pe...
# CGS  53a-102a       CGS  53a-102a charges dropped 25.0 percent  fr...
# CGS  53a-103a       CGS  53a-103a charges dropped 83.3333333333 pe...
# CGS  53a-211        CGS  53a-211 charges dropped 24.375 percent  f...
# CGS  53a-212        CGS  53a-212 charges dropped 12.3397435897 per...
# CGS  53a-216        CGS  53a-216 charges dropped 44.3855932203 per...
# CGS  53a-217        CGS  53a-217 charges dropped -36.319124424 per...
# CGS  53a-217a       CGS  53a-217a charges dropped 51.25 percent  f...
# CGS  53a-217c       CGS  53a-217c charges dropped -1.19154676259 p...
# CGS  29-38          CGS  29-38 charges dropped 5.2718495935 percen...
# CGS  53-206         CGS  53-206 charges dropped 26.7846475508 perc...
# CGS  53a-217b       CGS  53a-217b charges dropped 42.5595238095 pe...
#
#                                                             Sentence3
# statute
# CGS  29-28          <strong>CGS  29-28 charges</strong> dropped -9...
# CGS  29-33          <strong>CGS  29-33 charges</strong> dropped -2...
# CGS  29-34(a)       <strong>CGS  29-34(a) charges</strong> dropped...
# CGS  29-35(a)       <strong>CGS  29-35(a) charges</strong> dropped...
# CGS  29-35(b)       <strong>CGS  29-35(b) charges</strong> dropped...
# CGS  29-36          <strong>CGS  29-36 charges</strong> dropped -3...
# CGS  29-37e         <strong>CGS  29-37e charges</strong> dropped 1...
# CGS  29-37i         <strong>CGS  29-37i charges</strong> dropped 4...
# CGS  29-37j(c)      <strong>CGS  29-37j(c) charges</strong> droppe...
# CGS  53-202(b)      <strong>CGS  53-202(b) charges</strong> droppe...
# CGS  53-202(c)      <strong>CGS  53-202(c) charges</strong> droppe...
# CGS  53-202b(a)(1)  <strong>CGS  53-202b(a)(1) charges</strong> dr...
# CGS  53-202c        <strong>CGS  53-202c charges</strong> dropped ...
# CGS  53-202f        <strong>CGS  53-202f charges</strong> dropped ...
# CGS  53-202g        <strong>CGS  53-202g charges</strong> dropped ...
# CGS  53-202k        <strong>CGS  53-202k charges</strong> dropped ...
# CGS  53-202l        <strong>CGS  53-202l charges</strong> dropped ...
# CGS  53-202aa       <strong>CGS  53-202aa charges</strong> dropped...
# CGS  53-203         <strong>CGS  53-203 charges</strong> dropped -...
# CGS  53-204         <strong>CGS  53-204 charges</strong> dropped 6...
# CGS  53-205         <strong>CGS  53-205 charges</strong> dropped 6...
# CGS  53-206c        <strong>CGS  53-206c charges</strong> dropped ...
# CGS  53-206d(a)     <strong>CGS  53-206d(a) charges</strong> dropp...
# CGS  53a-55a        <strong>CGS  53a-55a charges</strong> dropped ...
# CGS  53a-56a        <strong>CGS  53a-56a charges</strong> dropped ...
# CGS  53a-60a        <strong>CGS  53a-60a charges</strong> dropped ...
# CGS  53a-60c        <strong>CGS  53a-60c charges</strong> dropped ...
# CGS  53a-72b        <strong>CGS  53a-72b charges</strong> dropped ...
# CGS  53a-92a        <strong>CGS  53a-92a charges</strong> dropped ...
# CGS  53a-94a        <strong>CGS  53a-94a charges</strong> dropped ...
# CGS  53a-102a       <strong>CGS  53a-102a charges</strong> dropped...
# CGS  53a-103a       <strong>CGS  53a-103a charges</strong> dropped...
# CGS  53a-211        <strong>CGS  53a-211 charges</strong> dropped ...
# CGS  53a-212        <strong>CGS  53a-212 charges</strong> dropped ...
# CGS  53a-216        <strong>CGS  53a-216 charges</strong> dropped ...
# CGS  53a-217        <strong>CGS  53a-217 charges</strong> dropped ...
# CGS  53a-217a       <strong>CGS  53a-217a charges</strong> dropped...
# CGS  53a-217c       <strong>CGS  53a-217c charges</strong> dropped...
# CGS  29-38          <strong>CGS  29-38 charges</strong> dropped 5....
# CGS  53-206         <strong>CGS  53-206 charges</strong> dropped 2...
# CGS  53a-217b       <strong>CGS  53a-217b charges</strong> dropped...

# %%
for s in top_df["Sentence"]: print s + "\n"
# Out:
# CGS  29-28 charges dropped 0.0 percent  from a 2010 peak of 10 to 10 in 2017.
#
# CGS  29-33 charges dropped 61.6504854369 percent  from a 2011 peak of 206 to 79 in 2017.
#
# CGS  29-34(a) charges dropped 0.0 percent  from a 2012 peak of 2 to 2 in 2017.
#
# CGS  29-35(a) charges dropped 4.69897209985 percent  from a 2008 peak of 681 to 649 in 2017.
#
# CGS  29-35(b) charges dropped 0.0 percent  from a 2017 peak of 112 to 112 in 2017.
#
# CGS  29-36 charges dropped 0.0 percent  from a 2017 peak of 115 to 115 in 2017.
#
# CGS  29-37e charges dropped 72.7272727273 percent  from a 2009 peak of 22 to 6 in 2017.
#
# CGS  29-37i charges dropped 50.0 percent  from a 2010 peak of 26 to 13 in 2017.
#
# CGS  29-37j(c) charges dropped 50.0 percent  from a 2005 peak of 2 to 1 in 2017.
#
# CGS  53-202(b) charges dropped 77.7777777778 percent  from a 2002 peak of 9 to 2 in 2017.
#
# CGS  53-202(c) charges dropped 66.6666666667 percent  from a 2004 peak of 9 to 3 in 2017.
#
# CGS  53-202b(a)(1) charges dropped 81.8181818182 percent  from a 2015 peak of 22 to 4 in 2017.
#
# CGS  53-202c charges dropped Year
# 2017    45.762712
# 2017    74.576271
# Name: Charges, dtype: float64 percent  from a 2016 peak of 59 to Year
# 2017    32
# 2017    15
# Name: Charges, dtype: int64 in 2017.
#
# CGS  53-202f charges dropped 0.0 percent  from a 2017 peak of 7 to 7 in 2017.
#
# CGS  53-202g charges dropped 57.1428571429 percent  from a 2012 peak of 7 to 3 in 2017.
#
# CGS  53-202k charges dropped 65.9090909091 percent  from a 2006 peak of 44 to 15 in 2017.
#
# CGS  53-202l charges dropped 0.0 percent  from a 2012 peak of 1 to 1 in 2017.
#
# CGS  53-202aa charges dropped 41.1764705882 percent  from a 2015 peak of 17 to 10 in 2017.
#
# CGS  53-203 charges dropped 17.0731707317 percent  from a 2006 peak of 205 to 170 in 2017.
#
# CGS  53-204 charges dropped 88.8888888889 percent  from a 2014 peak of 18 to 2 in 2017.
#
# CGS  53-205 charges dropped 77.7777777778 percent  from a 2010 peak of 18 to 4 in 2017.
#
# CGS  53-206c charges dropped 17.4418604651 percent  from a 2014 peak of 86 to 71 in 2017.
#
# CGS  53-206d(a) charges dropped 3.1914893617 percent  from a 2013 peak of 94 to 91 in 2017.
#
# CGS  53a-55a charges dropped 41.3793103448 percent  from a 2016 peak of 29 to 17 in 2017.
#
# CGS  53a-56a charges dropped 66.6666666667 percent  from a 2009 peak of 3 to 1 in 2017.
#
# CGS  53a-60a charges dropped 58.8235294118 percent  from a 2012 peak of 34 to 14 in 2017.
#
# CGS  53a-60c charges dropped 50.0 percent  from a 2011 peak of 4 to 2 in 2017.
#
# CGS  53a-72b charges dropped 0.0 percent  from a 2013 peak of 2 to 2 in 2017.
#
# CGS  53a-92a charges dropped 73.6842105263 percent  from a 2013 peak of 38 to 10 in 2017.
#
# CGS  53a-94a charges dropped 53.8461538462 percent  from a 2009 peak of 13 to 6 in 2017.
#
# CGS  53a-102a charges dropped 70.0 percent  from a 2008 peak of 10 to 3 in 2017.
#
# CGS  53a-103a charges dropped 88.8888888889 percent  from a 2008 peak of 9 to 1 in 2017.
#
# CGS  53a-211 charges dropped 52.380952381 percent  from a 2008 peak of 63 to 30 in 2017.
#
# CGS  53a-212 charges dropped 34.4680851064 percent  from a 2005 peak of 470 to 308 in 2017.
#
# CGS  53a-216 charges dropped 64.1304347826 percent  from a 2006 peak of 92 to 33 in 2017.
#
# CGS  53a-217 charges dropped 7.5 percent  from a 2013 peak of 640 to 592 in 2017.
#
# CGS  53a-217a charges dropped 72.2222222222 percent  from a 2013 peak of 18 to 5 in 2017.
#
# CGS  53a-217c charges dropped 24.4623655914 percent  from a 2011 peak of 372 to 281 in 2017.
#
# CGS  29-38 charges dropped 26.7871170463 percent  from a 2008 peak of 1273 to 932 in 2017.
#
# CGS  53-206 charges dropped 39.4268774704 percent  from a 2006 peak of 1012 to 613 in 2017.
#
# CGS  53a-217b charges dropped 65.7142857143 percent  from a 2005 peak of 35 to 12 in 2017.

# %%
for s in top_df["Sentence2"]: print s+ "\n"
# Out:
# CGS  29-28 charges dropped -98.6666666667 percent  from a 15-year average of 5 to 10 in 2017.
#
# CGS  29-33 charges dropped -23.5119047619 percent  from a 15-year average of 64 to 79 in 2017.
#
# CGS  29-34(a) charges dropped -80.0 percent  from a 15-year average of 1 to 2 in 2017.
#
# CGS  29-35(a) charges dropped -11.7469879518 percent  from a 15-year average of 581 to 649 in 2017.
#
# CGS  29-35(b) charges dropped -1298.33333333 percent  from a 15-year average of 8 to 112 in 2017.
#
# CGS  29-36 charges dropped -30.8948863636 percent  from a 15-year average of 88 to 115 in 2017.
#
# CGS  29-37e charges dropped 10.3896103896 percent  from a 15-year average of 7 to 6 in 2017.
#
# CGS  29-37i charges dropped 4.7619047619 percent  from a 15-year average of 14 to 13 in 2017.
#
# CGS  29-37j(c) charges dropped 50.0 percent  from a 15-year average of 2 to 1 in 2017.
#
# CGS  53-202(b) charges dropped 4.16666666667 percent  from a 15-year average of 2 to 2 in 2017.
#
# CGS  53-202(c) charges dropped 37.5 percent  from a 15-year average of 4 to 3 in 2017.
#
# CGS  53-202b(a)(1) charges dropped 38.7755102041 percent  from a 15-year average of 7 to 4 in 2017.
#
# CGS  53-202c charges dropped Year
# 2017   -50.317460
# 2017    30.634921
# Name: Charges, dtype: float64 percent  from a 15-year average of 21 to Year
# 2017    32
# 2017    15
# Name: Charges, dtype: int64 in 2017.
#
# CGS  53-202f charges dropped -260.0 percent  from a 15-year average of 2 to 7 in 2017.
#
# CGS  53-202g charges dropped 35.0 percent  from a 15-year average of 5 to 3 in 2017.
#
# CGS  53-202k charges dropped 16.3194444444 percent  from a 15-year average of 18 to 15 in 2017.
#
# CGS  53-202l charges dropped 0.0 percent  from a 15-year average of 1 to 1 in 2017.
#
# CGS  53-202aa charges dropped 12.7272727273 percent  from a 15-year average of 11 to 10 in 2017.
#
# CGS  53-203 charges dropped -0.739644970414 percent  from a 15-year average of 169 to 170 in 2017.
#
# CGS  53-204 charges dropped 67.8571428571 percent  from a 15-year average of 6 to 2 in 2017.
#
# CGS  53-205 charges dropped 67.6136363636 percent  from a 15-year average of 11 to 4 in 2017.
#
# CGS  53-206c charges dropped 10.1265822785 percent  from a 15-year average of 79 to 71 in 2017.
#
# CGS  53-206d(a) charges dropped -26.0802469136 percent  from a 15-year average of 72 to 91 in 2017.
#
# CGS  53a-55a charges dropped 3.08641975309 percent  from a 15-year average of 18 to 17 in 2017.
#
# CGS  53a-56a charges dropped 62.5 percent  from a 15-year average of 2 to 1 in 2017.
#
# CGS  53a-60a charges dropped 32.2222222222 percent  from a 15-year average of 20 to 14 in 2017.
#
# CGS  53a-60c charges dropped 22.2222222222 percent  from a 15-year average of 3 to 2 in 2017.
#
# CGS  53a-72b charges dropped -75.0 percent  from a 15-year average of 1 to 2 in 2017.
#
# CGS  53a-92a charges dropped 61.5384615385 percent  from a 15-year average of 26 to 10 in 2017.
#
# CGS  53a-94a charges dropped -24.4444444444 percent  from a 15-year average of 5 to 6 in 2017.
#
# CGS  53a-102a charges dropped 25.0 percent  from a 15-year average of 4 to 3 in 2017.
#
# CGS  53a-103a charges dropped 83.3333333333 percent  from a 15-year average of 6 to 1 in 2017.
#
# CGS  53a-211 charges dropped 24.375 percent  from a 15-year average of 40 to 30 in 2017.
#
# CGS  53a-212 charges dropped 12.3397435897 percent  from a 15-year average of 351 to 308 in 2017.
#
# CGS  53a-216 charges dropped 44.3855932203 percent  from a 15-year average of 59 to 33 in 2017.
#
# CGS  53a-217 charges dropped -36.319124424 percent  from a 15-year average of 434 to 592 in 2017.
#
# CGS  53a-217a charges dropped 51.25 percent  from a 15-year average of 10 to 5 in 2017.
#
# CGS  53a-217c charges dropped -1.19154676259 percent  from a 15-year average of 278 to 281 in 2017.
#
# CGS  29-38 charges dropped 5.2718495935 percent  from a 15-year average of 984 to 932 in 2017.
#
# CGS  53-206 charges dropped 26.7846475508 percent  from a 15-year average of 837 to 613 in 2017.
#
# CGS  53a-217b charges dropped 42.5595238095 percent  from a 15-year average of 21 to 12 in 2017.

# %%
for s in top_df["Sentence3"]: print s + "\n"

# %%
# yearly totals

fonly_df = df[df["Table"]!=2].groupby("Year").agg({"Charges":sum})
fonly_df["Title"] = "All firearm-only"
fonly_df.to_csv("data/firearm-only.csv")
fonly_df
# Out:
#       Charges             Title
# Year
# 2001      441  All firearm-only
# 2002     2069  All firearm-only
# 2003     2293  All firearm-only
# 2004     2109  All firearm-only
# 2005     2515  All firearm-only
# 2006     2488  All firearm-only
# 2007     1968  All firearm-only
# 2008     2821  All firearm-only
# 2009     2604  All firearm-only
# 2010     2684  All firearm-only
# 2011     2901  All firearm-only
# 2012     2574  All firearm-only
# 2013     2779  All firearm-only
# 2014     2623  All firearm-only
# 2015     2800  All firearm-only
# 2016     2615  All firearm-only
# 2017     2722  All firearm-only

# %%
prev_avg(fonly_df)
# Out:
# 2392.75

# %%
plot_offense(fonly_df,title="Firearm-only charges",figsize=(6,4))
# Out:
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')

# %%
maybe_df = df[df["Table"]==2].groupby("Year").agg({"Charges":sum})
maybe_df["Title"] = "All potential firearm-involved"
plot_offense(maybe_df,title="Potentially firearm",figsize=(6,4))
# Out:
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')

# %%
all_df = df[df["Table"]==2].groupby("Year").agg({"Charges":sum})
all_df["Title"] = "All offenses"
plot_offense(all_df,figsize=(6,4))
# Out:
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Year')

# %%
df.groupby("Year").agg({"Charges":sum}).to_csv("data/potential-firearm-charges.csv")
df.groupby("Year").agg({"Charges":sum})
# Out:
#       Charges
# Year
# 2001      877
# 2002     4104
# 2003     4472
# 2004     4246
# 2005     4637
# 2006     4650
# 2007     3739
# 2008     5119
# 2009     4650
# 2010     4740
# 2011     4895
# 2012     4326
# 2013     4461
# 2014     4213
# 2015     4445
# 2016     4182
# 2017     4279

# %%
df[df["Table"]==2].groupby("Year").agg({"Charges":sum})
# Out:
#       Charges
# Year
# 2001      436
# 2002     2035
# 2003     2179
# 2004     2137
# 2005     2122
# 2006     2162
# 2007     1771
# 2008     2298
# 2009     2046
# 2010     2056
# 2011     1994
# 2012     1752
# 2013     1682
# 2014     1590
# 2015     1645
# 2016     1567
# 2017     1557

# %%
df.groupby("Year").agg({"Charges":sum})
# Out:
#       Charges
# Year
# 2001      877
# 2002     4104
# 2003     4472
# 2004     4246
# 2005     4637
# 2006     4650
# 2007     3739
# 2008     5119
# 2009     4650
# 2010     4740
# 2011     4895
# 2012     4326
# 2013     4461
# 2014     4213
# 2015     4445
# 2016     4182
# 2017     4279

# %%
df.to_csv("data/combined-firearm-charges.csv",index=False)

# %%
df[df["Table"] == 2]["Title"].unique()
# Out:
# array(['Possessing a weapon in a vehicle', 'Carrying a dangerous weapon',
#        'Possessing a firearm or deadly weapon on school grounds',
#        'Possess firearm or deadly weapon on school ground'], dtype=object)

# %%
df.head()
# Out:
#    Year  Charges  Table                                     Title     Statute
# 0  2013        4    1.0  Violating pistol permitting requirements  CGS  29-28
# 1  2014        3    1.0  Violating pistol permitting requirements  CGS  29-28
# 2  2015        5    1.0  Violating pistol permitting requirements  CGS  29-28
# 3  2016        7    1.0  Violating pistol permitting requirements  CGS  29-28
# 4  2017       10    1.0  Violating pistol permitting requirements  CGS  29-28
